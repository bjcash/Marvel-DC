# %% [markdown]
# # Rotten Tomatoes Score vs Audience Review Score

# %%
#import packages from Bokeh needed for Visualization
import pandas as pd
from bokeh.io import output_notebook
from bokeh.io import show
from bokeh.plotting import figure
from bokeh.models import NumeralTickFormatter
from bokeh.models import ColumnDataSource
from bokeh.models import HoverTool
from bokeh.models import LinearInterpolator
from bokeh.models import CategoricalColorMapper
from ipywidgets import interact
from bokeh.io import push_notebook
import matplotlib as plt
from bokeh.layouts import row
output_notebook()

#read in data
data= pd.read_csv('C:\\Users\\benjc\\OneDrive\\Personal Development\\Live Oak Bank\\Marvel-DC.csv', 
                  index_col='Year', thousands=',')

#########################################################################################
####################Rotten Tomatoes Score (x-axis)#######################################
#########################################################################################

#change into column data soure so bokeh can read the data
source = ColumnDataSource(data)

#add a tool to the graph to hover over data points and retrieve information
hover = HoverTool(tooltips=[('Movie', '@Movie'),
                            ('Rotten Tomatoes Score', '@Rotten_Tomatoes_Score'), 
                            ('Box Office', '@BOS_Worldwide'),
                            ('Company', '@Marvel_DC'),
                            ('ROI', '@ROI')
                           ]) 

#add size to the circles based off ROI
size_mapper = LinearInterpolator(
        x=[data.ROI.min(), data.ROI.max()],
        y=[4,22]
)

#add color to the graph to distinquish Marvel and DC
color_mapper = CategoricalColorMapper(
       factors = ['Marvel', 'DC'], palette=['blue', 'red'])     
p1 = figure(tools=[hover, 'crosshair', 'pan', 'wheel_zoom'], title = 'Marvel vs. DC', height=600, width=900)

#creating a graph with circle plots, labeling axis, and coding in dollars for axis
p1.circle(data['Rotten_Tomatoes_Score'], data['BOS_Worldwide'], size={'field':'ROI','transform': size_mapper}, 
         hover_color='lime', color={'field':'Marvel_DC','transform': color_mapper}, source=source, legend='Marvel_DC')
p1.yaxis[0].formatter = NumeralTickFormatter(format = '$,')
p1.xaxis.axis_label = 'Rotten Tomatoes Score'
p1.yaxis.axis_label = 'Worldwide BOS'

#add legend and move to the right
p1.legend.location = (0, 80)
p1.legend.border_line_color = None
p1.right.append(p1.legend[0])

#display the plot
show(p1)

#########################################################################################
####################Audience Rewview Score (x-axis)######################################
#########################################################################################

source = ColumnDataSource(data)

hover = HoverTool(tooltips=[('Movie', '@Movie'),
                            ('Audience_Review_Score', '@Audience_Review_Score'), 
                            ('Box Office', '@BOS_Worldwide'),
                            ('Company', '@Marvel_DC'),
                            ('ROI', '@ROI')
                           ]) 

size_mapper = LinearInterpolator(
        x=[data.ROI.min(), data.ROI.max()],
        y=[4,22]
)

color_mapper = CategoricalColorMapper(
       factors = ['Marvel', 'DC'], palette=['blue', 'red']) 

p2 = figure(tools=[hover, 'crosshair', 'pan', 'wheel_zoom'], title = 'Marvel vs. DC', height=600, width=900)

p2.circle(data['Audience_Review_Score'], data['BOS_Worldwide'], size={'field':'ROI','transform': size_mapper}, 
         hover_color='lime', color={'field':'Marvel_DC','transform': color_mapper}, source=source, legend='Marvel_DC')
p2.yaxis[0].formatter = NumeralTickFormatter(format = '$,')
p2.xaxis.axis_label = 'Audience Review Score'
p2.yaxis.axis_label = 'Worldwide BOS'

#add legend and move to the right
p2.legend.location = (0, 80)
p2.legend.border_line_color = None
p2.right.append(p2.legend[0])

show(p2)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d1de4003-c83d-4a18-9536-303561268cce">Loading BokehJS ...</span>
#     </div>
# C:\ProgramData\Anaconda3\lib\site-packages\bokeh\util\deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# C:\ProgramData\Anaconda3\lib\site-packages\bokeh\util\deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="23b46161-77b3-49bc-8671-85a26a7feaf5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("23b46161-77b3-49bc-8671-85a26a7feaf5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("23b46161-77b3-49bc-8671-85a26a7feaf5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '23b46161-77b3-49bc-8671-85a26a7feaf5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9b43db8b-2270-4364-bf5e-1f7d36ea6cc7":{"roots":{"references":[{"attributes":{"callback":null,"plot":{"id":"7bc91bc0-6345-4885-834b-c7450e982974","subtype":"Figure","type":"Plot"},"tooltips":[["Movie","@Movie"],["Rotten Tomatoes Score","@Rotten_Tomatoes_Score"],["Box Office","@BOS_Worldwide"],["Company","@Marvel_DC"],["ROI","@ROI"]]},"id":"9c7b08e7-d736-4b77-b921-559fd3e86c18","type":"HoverTool"},{"attributes":{},"id":"eccca8bc-00ed-4024-9cd3-5ee87589a245","type":"BasicTicker"},{"attributes":{"plot":{"id":"7bc91bc0-6345-4885-834b-c7450e982974","subtype":"Figure","type":"Plot"}},"id":"f1394922-c527-41a4-b601-d81a67ed7610","type":"PanTool"},{"attributes":{"plot":{"id":"7bc91bc0-6345-4885-834b-c7450e982974","subtype":"Figure","type":"Plot"}},"id":"ab69e750-0fdd-406e-91c2-4fe99b30a123","type":"WheelZoomTool"},{"attributes":{},"id":"ba80b552-3f91-4363-b984-28948b354239","type":"ToolEvents"},{"attributes":{"factors":["Marvel","DC"],"palette":["blue","red"]},"id":"3bfeef0d-cf1d-44a9-80f7-059715c8ca36","type":"CategoricalColorMapper"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"field":"ROI","transform":{"id":"b7ec3012-27f1-45cc-9795-3b4b9358141a","type":"LinearInterpolator"},"units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"eddf53a6-b7ea-45ff-a4fe-a599356cc94b","type":"Circle"},{"attributes":{"format":"$,"},"id":"7e7399cf-f756-43ea-ae9f-676df3bf1167","type":"NumeralTickFormatter"},{"attributes":{"label":{"field":"Marvel_DC"},"renderers":[{"id":"aa4fb6b2-e3fb-4d05-b654-a2a56f3c69a7","type":"GlyphRenderer"}]},"id":"9894e398-a6c3-4ef4-ba52-3611014c7680","type":"LegendItem"},{"attributes":{"below":[{"id":"60a2ff1a-5a73-4844-a329-aeeb5e5d43dd","type":"LinearAxis"}],"left":[{"id":"ea9090fd-0ab0-44bc-bc50-f382025b1669","type":"LinearAxis"}],"plot_width":900,"renderers":[{"id":"60a2ff1a-5a73-4844-a329-aeeb5e5d43dd","type":"LinearAxis"},{"id":"a16a1680-6d70-4f17-a02d-ba44be627f41","type":"Grid"},{"id":"ea9090fd-0ab0-44bc-bc50-f382025b1669","type":"LinearAxis"},{"id":"5cab9cad-6825-43d7-baef-56364ddb8ba9","type":"Grid"},{"id":"71c9f61a-f2af-44e2-874c-72fe75905d35","type":"Legend"},{"id":"aa4fb6b2-e3fb-4d05-b654-a2a56f3c69a7","type":"GlyphRenderer"}],"right":[{"id":"71c9f61a-f2af-44e2-874c-72fe75905d35","type":"Legend"}],"title":{"id":"79e216cd-26f0-4401-aa96-4afc39b65e28","type":"Title"},"tool_events":{"id":"ba80b552-3f91-4363-b984-28948b354239","type":"ToolEvents"},"toolbar":{"id":"cb83f9a5-3de4-466f-adaa-1307283db5a0","type":"Toolbar"},"x_range":{"id":"fb725cac-6780-435c-9af0-74c0412027aa","type":"DataRange1d"},"y_range":{"id":"9069bc89-5aa9-4942-a4bd-93a2ba142d0e","type":"DataRange1d"}},"id":"7bc91bc0-6345-4885-834b-c7450e982974","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"d4cc671e-5b5e-4b3f-88b7-000d49c620da","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"7bc91bc0-6345-4885-834b-c7450e982974","subtype":"Figure","type":"Plot"},"ticker":{"id":"4b0daeab-404e-4f04-ae7d-05b4b3843899","type":"BasicTicker"}},"id":"5cab9cad-6825-43d7-baef-56364ddb8ba9","type":"Grid"},{"attributes":{"callback":null},"id":"fb725cac-6780-435c-9af0-74c0412027aa","type":"DataRange1d"},{"attributes":{"fill_color":{"field":"Marvel_DC","transform":{"id":"3bfeef0d-cf1d-44a9-80f7-059715c8ca36","type":"CategoricalColorMapper"}},"line_color":{"field":"Marvel_DC","transform":{"id":"3bfeef0d-cf1d-44a9-80f7-059715c8ca36","type":"CategoricalColorMapper"}},"size":{"field":"ROI","transform":{"id":"b7ec3012-27f1-45cc-9795-3b4b9358141a","type":"LinearInterpolator"},"units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"94d6cc40-f35c-436e-bd91-f057a2ea075e","type":"Circle"},{"attributes":{"border_line_color":{"value":null},"items":[{"id":"9894e398-a6c3-4ef4-ba52-3611014c7680","type":"LegendItem"}],"location":[0,80],"plot":{"id":"7bc91bc0-6345-4885-834b-c7450e982974","subtype":"Figure","type":"Plot"}},"id" ...
# C:\ProgramData\Anaconda3\lib\site-packages\bokeh\util\deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# C:\ProgramData\Anaconda3\lib\site-packages\bokeh\util\deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2f4fbe2b-96a4-4fc7-b591-f43f4e132b67"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2f4fbe2b-96a4-4fc7-b591-f43f4e132b67");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2f4fbe2b-96a4-4fc7-b591-f43f4e132b67");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2f4fbe2b-96a4-4fc7-b591-f43f4e132b67' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5982e7f5-3b4d-4926-a083-d836b2db390f":{"roots":{"references":[{"attributes":{"data_source":{"id":"9a7d6a33-d0d8-411a-92c2-92ff573c7529","type":"ColumnDataSource"},"glyph":{"id":"c040cb1f-c0e5-4405-a76b-ac9c4467cb67","type":"Circle"},"hover_glyph":{"id":"ef1c846e-8d6e-4b8e-b2d1-e96947025cf8","type":"Circle"},"muted_glyph":null,"nonselection_glyph":{"id":"3c3f5608-71f5-4f9d-a3de-3bb4dac7333f","type":"Circle"},"selection_glyph":null},"id":"35d3ddd6-4440-4d52-8d67-719b735bba73","type":"GlyphRenderer"},{"attributes":{"axis_label":"Worldwide BOS","formatter":{"id":"990e402b-1c88-4320-b045-441ec5fcc494","type":"NumeralTickFormatter"},"plot":{"id":"be6b68ee-2c07-414c-b717-de974cc1c570","subtype":"Figure","type":"Plot"},"ticker":{"id":"6f893f6c-8301-4582-bc9a-c8f87956ef96","type":"BasicTicker"}},"id":"a39cbee9-0cf4-4544-8a7f-2b4896060ca5","type":"LinearAxis"},{"attributes":{"factors":["Marvel","DC"],"palette":["blue","red"]},"id":"1879f6d9-b26e-46b9-b16f-ea7a2f80f413","type":"CategoricalColorMapper"},{"attributes":{"border_line_color":{"value":null},"items":[{"id":"d3adc503-d612-441c-ae75-339ff6d2d847","type":"LegendItem"}],"location":[0,80],"plot":{"id":"be6b68ee-2c07-414c-b717-de974cc1c570","subtype":"Figure","type":"Plot"}},"id":"64578539-de5f-4506-af4d-ad403667785b","type":"Legend"},{"attributes":{},"id":"49b69300-353b-4cf4-8810-58c476e729a0","type":"BasicTicker"},{"attributes":{"label":{"field":"Marvel_DC"},"renderers":[{"id":"35d3ddd6-4440-4d52-8d67-719b735bba73","type":"GlyphRenderer"}]},"id":"d3adc503-d612-441c-ae75-339ff6d2d847","type":"LegendItem"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"bdbd1378-9be7-4a56-b952-f431b294b6f5","type":"HoverTool"},{"id":"189d986f-1f66-4025-9603-3a2eb3e5eea3","type":"CrosshairTool"},{"id":"3c62fe2c-e873-4944-acaa-2d778cba83cc","type":"PanTool"},{"id":"423d5288-bc72-4f6a-9aad-3f60dbe1b9bf","type":"WheelZoomTool"}]},"id":"83c430f9-6748-4d84-9476-b4b0609a3f86","type":"Toolbar"},{"attributes":{"format":"$,"},"id":"990e402b-1c88-4320-b045-441ec5fcc494","type":"NumeralTickFormatter"},{"attributes":{"callback":null,"plot":{"id":"be6b68ee-2c07-414c-b717-de974cc1c570","subtype":"Figure","type":"Plot"},"tooltips":[["Movie","@Movie"],["Audience_Review_Score","@Audience_Review_Score"],["Box Office","@BOS_Worldwide"],["Company","@Marvel_DC"],["ROI","@ROI"]]},"id":"bdbd1378-9be7-4a56-b952-f431b294b6f5","type":"HoverTool"},{"attributes":{},"id":"6015d5a0-2bf6-4832-ac77-5fe1df2d2bd4","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"Marvel vs. DC"},"id":"45e5cad9-f944-4ee8-86d4-cd34e10030db","type":"Title"},{"attributes":{"plot":{"id":"be6b68ee-2c07-414c-b717-de974cc1c570","subtype":"Figure","type":"Plot"}},"id":"3c62fe2c-e873-4944-acaa-2d778cba83cc","type":"PanTool"},{"attributes":{"fill_color":{"field":"Marvel_DC","transform":{"id":"1879f6d9-b26e-46b9-b16f-ea7a2f80f413","type":"CategoricalColorMapper"}},"line_color":{"field":"Marvel_DC","transform":{"id":"1879f6d9-b26e-46b9-b16f-ea7a2f80f413","type":"CategoricalColorMapper"}},"size":{"field":"ROI","transform":{"id":"173f49b7-d6b2-42cc-be60-075f416fa196","type":"LinearInterpolator"},"units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c040cb1f-c0e5-4405-a76b-ac9c4467cb67","type":"Circle"},{"attributes":{"callback":null,"column_names":["Movie","Rotten_Tomatoes_Score","Audience_Review_Score","BOS_Worldwide","BOS_Domestic","BOS_International","Marvel_DC","Production_Budget","ROI","Year","x","y"],"data":{"Audience_Review_Score":[88,88,88,86,89,86,83,92,92,77,78,91,74,76,72,71,91,77,88,60,63,75,66,90,58,69,90,94,90,94,67,81,51,77,64,91,61,85,87,18,45,35,81,57,18,71,59,68,63,45,44,61,29,47,90,32,25,20,42,51,53],"BOS_Domestic":[314334584,334201140,389813101,232641920,408084349,180202163,459005868,333176600,259766572,206362140,409013994,623357910,176654505,181030624,312433331,134806913,318412101,228574516,412563408,325100054,330360194,291045518,155442489,363070709 ...

# %% [markdown]
# # Graph with Slider by Year

# %%
import pandas as pd
from bokeh.io import output_notebook
from bokeh.io import show
from bokeh.plotting import figure
from bokeh.models import NumeralTickFormatter
from bokeh.models import ColumnDataSource
from bokeh.models import HoverTool
from bokeh.models import LinearInterpolator
from bokeh.models import CategoricalColorMapper
from ipywidgets import interact
from bokeh.io import push_notebook
output_notebook()
data= pd.read_csv('C:\\Users\\benjc\\OneDrive\\Personal Development\\Live Oak Bank\\Marvel-DC.csv', 
                  index_col='Year', thousands=',')

#defining source column data based off year
source = ColumnDataSource(dict(
        x=data.loc[2017].Rotten_Tomatoes_Score,
        y=data.loc[2017].BOS_Worldwide,
        x_2=data.loc[2017].Audience_Review_Score,
        ROI=data.loc[2017].ROI,
        producer=data.loc[2017].Marvel_DC,
        movie=data.loc[2017].Movie
        ))
size_mapper = LinearInterpolator(
        x=[data.ROI.min(), data.ROI.max()],
        y=[4,35]
)
color_mapper = CategoricalColorMapper(
       factors = ['Marvel', 'DC'], palette=['blue', 'red'])

#changing color to Marvel_DC
hover = HoverTool (tooltips=[('Movie', '@movie'),
                            ('Rotten Tomatoes Score', '@x'),
                            ('Audience Review Score', '@x_2'),
                            ('Box Office', '@y'),
                            ('Producer', '@producer'),
                            ('ROI', '@ROI')])

p = figure(tools=[hover], height=500, width=800)
p.circle(x='x', y='y', size={'field':'ROI','transform': size_mapper}, 
         color={'field':'producer','transform': color_mapper}, source=source, legend='producer')
p.yaxis[0].formatter = NumeralTickFormatter(format = '$,')
p.xaxis.axis_label = 'Rotten Tomatoes Score'
p.yaxis.axis_label = 'Worldwide BOS'

#add legend and move to the right
p.legend.location = (0, 80)
p.legend.border_line_color = None
p.right.append(p.legend[0])

#creating a function for year to then create a slider
def update(year):
    new_data = dict(
    x=data.loc[year].Rotten_Tomatoes_Score,
    y=data.loc[year].BOS_Worldwide,
    x_2=data.loc[year].Audience_Review_Score,
    ROI=data.loc[year].ROI,
    producer=data.loc[year].Marvel_DC,
    movie=data.loc[year].Movie
    )
    source.data = new_data
    p.title.text='Year'
    push_notebook()

#interacting the slider with year and corresponding graph
interact(update, year=(2002, 2017, 1))

#display plot
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="970da07e-224b-43d9-aa46-2e167e641a7d">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="80502d0b-1725-4dd4-8c5b-c537deb58ee4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("80502d0b-1725-4dd4-8c5b-c537deb58ee4");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("c9b746a1-a840-4b5d-80b1-dd98412e7f00", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("80502d0b-1725-4dd4-8c5b-c537deb58ee4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '80502d0b-1725-4dd4-8c5b-c537deb58ee4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"835d5125-3071-4962-bdc5-60cff2fbf660":{"roots":{"references":[{"attributes":{"border_line_color":{"value":null},"items":[{"id":"11040ec9-7b16-4c42-b96c-d58001ccc3ae","type":"LegendItem"}],"location":[0,80],"plot":{"id":"2b92cf12-8d61-4680-9cfa-77dae18fecbe","subtype":"Figure","type":"Plot"}},"id":"719d4e63-d922-4257-b4a4-2a8cd6ec6d1a","type":"Legend"},{"attributes":{"axis_label":"Worldwide BOS","formatter":{"id":"7cdb9ab7-af5d-4084-b82d-a6a8c626f911","type":"NumeralTickFormatter"},"plot":{"id":"2b92cf12-8d61-4680-9cfa-77dae18fecbe","subtype":"Figure","type":"Plot"},"ticker":{"id":"d95a05d8-2ee2-4203-b60e-2309b3f95677","type":"BasicTicker"}},"id":"b92f6990-4e00-449b-842d-717bb53b1ec5","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y","x_2","ROI","producer","movie"],"data":{"ROI":{"__ndarray__":"w8EYcBrL9z/gkcIGVTTbPw==","dtype":"float64","shape":[2]},"movie":["X-Men Origins: Wolverine","Watchmen"],"producer":["Marvel","DC"],"x":[38,64],"x_2":[58,71],"y":[373062864,185258983]}},"id":"aba85840-08e4-437b-a019-e8325a39c751","type":"ColumnDataSource"},{"attributes":{"data":null,"x":[-0.7680146379999999,12.50194791],"y":[4,35]},"id":"351ca4ef-7bb5-4c9a-8bee-07bc2afee702","type":"LinearInterpolator"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"field":"ROI","transform":{"id":"351ca4ef-7bb5-4c9a-8bee-07bc2afee702","type":"LinearInterpolator"},"units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1ac64ca4-ad9a-4a52-9277-736eb11f4098","type":"Circle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4be388a9-15ca-45d2-8419-7b574576d59d","type":"HoverTool"}]},"id":"aa1ad098-3943-4e24-972a-7d0e78438faa","type":"Toolbar"},{"attributes":{},"id":"d95a05d8-2ee2-4203-b60e-2309b3f95677","type":"BasicTicker"},{"attributes":{"plot":{"id":"2b92cf12-8d61-4680-9cfa-77dae18fecbe","subtype":"Figure","type":"Plot"},"ticker":{"id":"654cf55f-ffc8-4484-87f3-092f5c872732","type":"BasicTicker"}},"id":"8ad0deaf-5522-402e-a4e4-06637707bea2","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"2b92cf12-8d61-4680-9cfa-77dae18fecbe","subtype":"Figure","type":"Plot"},"ticker":{"id":"d95a05d8-2ee2-4203-b60e-2309b3f95677","type":"BasicTicker"}},"id":"6a5c8553-07e8-417b-8d76-f15f976f07b6","type":"Grid"},{"attributes":{"factors":["Marvel","DC"],"palette":["blue","red"]},"id":"db85d7de-442f-41da-ba7b-0d5808c2a303","type":"CategoricalColorMapper"},{"attributes":{"label":{"field":"producer"},"renderers":[{"id":"2dff91d2-ee17-4e8e-96e2-ffcfeb9a4416","type":"GlyphRenderer"}]},"id":"11040ec9-7b16-4c42-b96c-d58001ccc3ae","type":"LegendItem"},{"attributes":{"data_source":{"id":"aba85840-08e4-437b-a019-e8325a39c751","type":"ColumnDataSource"},"glyph":{"id":"d082a5d7-0d38-4633-925f-562fc13e3f50","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1ac64ca4-ad9a-4a52-9277-736eb11f4098","type":"Circle"},"selection_glyph":null},"id":"2dff91d2-ee17-4e8e-96e2-ffcfeb9a4416","type":"GlyphRenderer"},{"attributes":{},"id":"3e300537-a366-4a03-be4b-abb688d9126d","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Rotten Tomatoes Score","formatter":{"id":"3e300537-a366-4a03-be4b-abb688d9126d","type":"BasicTickFormatter"},"plot":{"id":"2b92cf12-8d61-4680-9cfa-77dae18fecbe","subtype":"Figure","type":"Plot"},"ticker":{"id":"654cf55f-ffc8-4484-87f3-092f5c872732","type":"BasicTicker"}},"id":"32050d79-ee60-49aa-9cca-dd3549b54683","type":"LinearAxis"},{"attributes":{"fill_color":{"field":"producer","transform":{"id":"db85d7de-442f-41da-ba7b-0d5808c2a303","type":"CategoricalColorMapper"}},"line_color":{"field":"producer","transform":{"id":"db85d7de-442f-41da-ba7b-0d5808c2a303","type":"CategoricalColorMapper"}},"size":{"field":"ROI","transform":{"id":"351ca4ef-7bb5-4c9a-8bee-07bc2afee702","type":"LinearInterpolator"},"units":"screen"},"x":{"field":"x"}," ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[126]</strong>&gt;</code></p>
